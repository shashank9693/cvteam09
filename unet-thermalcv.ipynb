# %%
################################################################################
# 1. IMPORT LIBRARIES
################################################################################
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report, precision_recall_curve, auc

################################################################################
# 2. LOAD DATASET (FIXED PATH)
################################################################################
DATASET_PATH = "/kaggle/input/healthythermal1"  # Update with correct path
IMG_SIZE = (224, 224)
BATCH_SIZE = 32
NUM_CLASSES = len(os.listdir(DATASET_PATH))  # Automatically detects classes

# Image Data Generators
datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    validation_split=0.2,  # 80% train, 20% validation
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=20
)

train_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="training"
)

val_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode="categorical",
    subset="validation"
)

print("Train samples:", train_gen.samples)
print("Validation samples:", val_gen.samples)

################################################################################
# 3. DEFINE U-NET MODEL
################################################################################
def unet_model(input_shape=(224,224,3), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)

    # Encoder (Downsampling)
    conv1 = layers.Conv2D(64, (3,3), activation="relu", padding="same")(inputs)
    conv1 = layers.Conv2D(64, (3,3), activation="relu", padding="same")(conv1)
    pool1 = layers.MaxPooling2D((2,2))(conv1)

    conv2 = layers.Conv2D(128, (3,3), activation="relu", padding="same")(pool1)
    conv2 = layers.Conv2D(128, (3,3), activation="relu", padding="same")(conv2)
    pool2 = layers.MaxPooling2D((2,2))(conv2)

    conv3 = layers.Conv2D(256, (3,3), activation="relu", padding="same")(pool2)
    conv3 = layers.Conv2D(256, (3,3), activation="relu", padding="same")(conv3)
    pool3 = layers.MaxPooling2D((2,2))(conv3)

    # Bottleneck
    conv4 = layers.Conv2D(512, (3,3), activation="relu", padding="same")(pool3)
    conv4 = layers.Conv2D(512, (3,3), activation="relu", padding="same")(conv4)

    # Decoder (Upsampling)
    up5 = layers.Conv2DTranspose(256, (2,2), strides=(2,2), padding="same")(conv4)
    merge5 = layers.concatenate([up5, conv3])
    conv5 = layers.Conv2D(256, (3,3), activation="relu", padding="same")(merge5)
    conv5 = layers.Conv2D(256, (3,3), activation="relu", padding="same")(conv5)

    up6 = layers.Conv2DTranspose(128, (2,2), strides=(2,2), padding="same")(conv5)
    merge6 = layers.concatenate([up6, conv2])
    conv6 = layers.Conv2D(128, (3,3), activation="relu", padding="same")(merge6)
    conv6 = layers.Conv2D(128, (3,3), activation="relu", padding="same")(conv6)

    up7 = layers.Conv2DTranspose(64, (2,2), strides=(2,2), padding="same")(conv6)
    merge7 = layers.concatenate([up7, conv1])
    conv7 = layers.Conv2D(64, (3,3), activation="relu", padding="same")(merge7)
    conv7 = layers.Conv2D(64, (3,3), activation="relu", padding="same")(conv7)

    # Classification Head
    global_avg = layers.GlobalAveragePooling2D()(conv7)
    outputs = layers.Dense(num_classes, activation="softmax")(global_avg)

    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# Create U-Net model
model = unet_model()
model.compile(optimizer=Adam(learning_rate=1e-4), loss="categorical_crossentropy", metrics=["accuracy"])
model.summary()

################################################################################
# 4. TRAIN THE MODEL
################################################################################
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=15,
    verbose=1
)

################################################################################
# 5. SAVE THE MODEL
################################################################################
model.save("/kaggle/working/U-Net_model.h5")

################################################################################
# 6. PLOT TRAINING HISTORY
################################################################################
def plot_history(history):
    fig, ax = plt.subplots(1, 2, figsize=(12, 5))

    # Accuracy Plot
    ax[0].plot(history.history["accuracy"], label="Train Accuracy")
    ax[0].plot(history.history["val_accuracy"], label="Validation Accuracy")
    ax[0].set_title("Training and Validation Accuracy")
    ax[0].set_xlabel("Epochs")
    ax[0].set_ylabel("Accuracy")
    ax[0].legend()

    # Loss Plot
    ax[1].plot(history.history["loss"], label="Train Loss")
    ax[1].plot(history.history["val_loss"], label="Validation Loss")
    ax[1].set_title("Training and Validation Loss")
    ax[1].set_xlabel("Epochs")
    ax[1].set_ylabel("Loss")
    ax[1].legend()

    plt.show()

plot_history(history)

################################################################################
# 7. EVALUATE ON THE TEST SET
################################################################################
test_loss, test_acc = model.evaluate(val_gen)
print(f"Test Accuracy: {test_acc:.4f}")

################################################################################
# 8. MULTI-CLASS PRECISION-RECALL CURVES
################################################################################
# Get true labels & predictions
y_true = val_gen.classes
y_pred_probs = model.predict(val_gen)

# Convert labels to one-hot encoding
y_true_one_hot = tf.keras.utils.to_categorical(y_true, num_classes=NUM_CLASSES)

plt.figure(figsize=(8, 6))
for i in range(NUM_CLASSES):
    precision, recall, _ = precision_recall_curve(y_true_one_hot[:, i], y_pred_probs[:, i])
    pr_auc = auc(recall, precision)
    plt.plot(recall, precision, label=f"Class {i} (AUC={pr_auc:.2f})")

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curves for All Classes")
plt.legend(bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

################################################################################
# 9. PRINT CLASSIFICATION REPORT
################################################################################
y_pred_labels = np.argmax(y_pred_probs, axis=1)
print(classification_report(y_true, y_pred_labels))
# Out:
# Found 511 images belonging to 6 classes.
# Found 125 images belonging to 6 classes.
# Train samples: 511
# Validation samples: 125
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 224, 224, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 224, 224, 64)   │          1,792 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 224, 224, 64)   │         36,928 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 112, 112, 64)   │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 112, 112, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 112, 112, 128)  │        147,584 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 56, 56, 128)    │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 56, 56, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 56, 56, 256)    │        590,080 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 28, 28, 256)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 28, 28, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 28, 28, 512)    │      2,359,808 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 56, 56, 256)    │        524,544 │ conv2d_7[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 56, 56, 512)    │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 56, 56, 256)    │      1,179,904 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 56, 56, 256)    │        590,080 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 112, 112, 128)  │        131,200 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 112, 112, 256)  │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 112, 112, 128)  │        295,040 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 112, 112, 128)  │        147,584 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 224, 224, 64)   │         32,832 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 224, 224, 128)  │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 224, 224, 64)   │         73,792 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 224, 224, 64)   │         36,928 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 64)             │              0 │ conv2d_13[0][0]        │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 6)              │            390 │ global_average_poolin… │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 7,697,670 (29.36 MB)
#  Trainable params: 7,697,670 (29.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1022s 64s/step - accuracy: 0.2652 - loss: 1.7707 - val_accuracy: 0.3520 - val_loss: 1.6486
# Epoch 2/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1011s 63s/step - accuracy: 0.3610 - loss: 1.6508 - val_accuracy: 0.3520 - val_loss: 1.6198
# Epoch 3/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1011s 63s/step - accuracy: 0.3606 - loss: 1.6054 - val_accuracy: 0.3520 - val_loss: 1.6219
# Epoch 4/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1013s 63s/step - accuracy: 0.3718 - loss: 1.6119 - val_accuracy: 0.3520 - val_loss: 1.6079
# Epoch 5/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1005s 63s/step - accuracy: 0.3449 - loss: 1.5557 - val_accuracy: 0.4160 - val_loss: 1.5905
# Epoch 6/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1005s 63s/step - accuracy: 0.3327 - loss: 1.5457 - val_accuracy: 0.4640 - val_loss: 1.5636
# Epoch 7/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1045s 63s/step - accuracy: 0.3483 - loss: 1.5222 - val_accuracy: 0.4640 - val_loss: 1.5508
# Epoch 8/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1006s 63s/step - accuracy: 0.3661 - loss: 1.4665 - val_accuracy: 0.4560 - val_loss: 1.4994
# Epoch 9/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1008s 63s/step - accuracy: 0.3504 - loss: 1.4871 - val_accuracy: 0.4720 - val_loss: 1.5077
# Epoch 10/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1020s 64s/step - accuracy: 0.3837 - loss: 1.4732 - val_accuracy: 0.4800 - val_loss: 1.4900
# Epoch 11/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1008s 63s/step - accuracy: 0.3560 - loss: 1.4627 - val_accuracy: 0.4160 - val_loss: 1.5138
# Epoch 12/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1010s 63s/step - accuracy: 0.3757 - loss: 1.4673 - val_accuracy: 0.4800 - val_loss: 1.5204
# Epoch 13/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1011s 63s/step - accuracy: 0.3956 - loss: 1.4177 - val_accuracy: 0.4080 - val_loss: 1.5400
# Epoch 14/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1010s 63s/step - accuracy: 0.3881 - loss: 1.4323 - val_accuracy: 0.3760 - val_loss: 1.5865
# Epoch 15/15
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1014s 63s/step - accuracy: 0.4888 - loss: 1.2954 - val_accuracy: 0.4880 - val_loss: 1.5646
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 72s 18s/step - accuracy: 0.4648 - loss: 1.5410
# Test Accuracy: 0.4720
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 73s 18s/step
#               precision    recall  f1-score   support
#
#            0       0.37      0.70      0.48        44
#            1       0.00      0.00      0.00        13
#            2       0.00      0.00      0.00        18
#            3       0.24      0.36      0.29        28
#            4       0.00      0.00      0.00         6
#            5       0.00      0.00      0.00        16
#
#     accuracy                           0.33       125
#    macro avg       0.10      0.18      0.13       125
# weighted avg       0.18      0.33      0.24       125
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
